# %%
import pickle
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl 
import csv
import brainx.modularity as mod
# Out:
# c:\Python27\lib\site-packages\brainx\__init__.py:30: UserWarning: Monkeypatching NetworkX's Watts-Strogatz routine
#   warnings.warn("Monkeypatching NetworkX's Watts-Strogatz routine")

# %%
import blumex

# %% [markdown]
# #Load Data

# %%
filestub=('C:\\Users\\Robert\\gitrepos\\cocomac-tools-rsblume\\applications\\ModhaSingh_PFC\\modha\lowest_full_g.pck')
whole_low=pickle.load(open(filestub, "rb"))

# %%
labels_list=['pfc_labels', 'mod_dlpfc_labels', 'mod_vlpfc_labels', 'mod_mpfc_labels', 'lit_dlpfc_labels', 'lit_vlpfc_labels', 'mod_lateral_labels', 'mod_rostral_labels', 'mod_premotor_labels', 'mod_lateral_labels_noF_add6v', 'lit_pfc_labels', 'lit_pfc_labels2' ]
labels={x : list(csv.reader(open(x + '.csv')))[0] for x in labels_list}
nlabels={x : len(labels[x]) for x in labels_list}

# %% [markdown]
# #Start working with data

# %%
whole_low=whole_low.to_undirected()
pfc_graph=whole_low.subgraph(labels['pfc_labels'])
mod_lat6v_graph=whole_low.subgraph(labels['mod_lateral_labels_noF_add6v'])
lit_lat_graph=whole_low.subgraph(labels['lit_pfc_labels'])
lit_lat_graph2=whole_low.subgraph(labels['lit_pfc_labels2'])

# %%
labels['lit_pfc_labels2']
# Out:
# ['44',
#  '46v',
#  '45A',
#  '47/12',
#  '45B',
#  '9/46v',
#  'L9',
#  'D9',
#  '8B',
#  'M9',
#  '46d',
#  '9/46d',
#  '8Ad']

# %%
pfc_bx_g,pfc_relabel_dict=blumex.make_brainx_graph(mod_lat6v_graph)
lit_bx_g, lit_relabel_dict=blumex.make_brainx_graph(lit_lat_graph)
lit_bx_g2, lit_relabel_dict2=blumex.make_brainx_graph(lit_lat_graph2)

# %%
print lit_relabel_dict2
# Out:
# {0: '46d', 1: '47/12', 2: '8B', 3: '9/46v', 4: '44', 5: '46v', 6: '8Ad', 7: 'D9', 8: '45A', 9: '45B', 10: '9/46d', 11: 'M9', 12: 'L9'}

# %%
print lit_relabel_dict
# Out:
# {0: '9/46d', 1: '46d', 2: '47/12', 3: '8B', 4: '9/46v', 5: '44', 6: '46v', 7: '46vr', 8: '8Ad', 9: 'D9', 10: '46dr', 11: '45A', 12: '45B', 13: '46f', 14: 'M9', 15: 'L9'}

# %%
lit2_simaneal=mod.simulated_annealing(lit_bx_g2)
# Out:
# T: 5.00e+01 energy: 9.76e-02 best: -9.12e-02
# T: 4.98e+01
#  energy: 1.42e-01 best: -9.12e-02
# T: 4.95e+01
#  energy: -6.95e-02 best: -1.23e-01
# T: 4.93e+01
#  energy: 1.31e-01 best: -1.23e-01
# T: 4.90e+01
#  energy: 1.26e-01 best: -1.23e-01
# T: 4.88e+01
#  energy: 8.99e-02 best: -1.23e-01
# T: 4.85e+01
#  energy: 1.28e-01 best: -1.23e-01
# T: 4.83e+01
#  energy: -1.59e-02 best: -1.23e-01
#  energy: 9.12e-02 best: -7.02e-02
# T: 4.78e+01
#  energy: 9.50e-02 best: -7.02e-02
# T: 4.76e+01
#  energy: 9.69e-02 best: -7.02e-02
# T: 4.73e+01
#  energy: -4.40e-02 best: -7.02e-02
# T: 4.71e+01
#  energy: -8.29e-03 best: -7.02e-02
# T: 4.68e+01
#  energy: 6.38e-02 best: -1.07e-01
# T: 4.66e+01
#  energy: 9.18e-02 best: -1.07e-01
# T: 4.64e+01
#  energy: 7.78e-02 best: -1.07e-01
# T: 4.61e+01
#  energy: 1.00e-01 best: -1.07e-01
# T: 4.59e+01
#  energy: 7.27e-02 best: -1.07e-01
# T: 4.57e+01
#  energy: 6.31e-02 best: -1.07e-01
# T: 4.55e+01
#  energy: 5.48e-02 best: -1.07e-01
# ...

# %%
pfc_simaneal[0].modularity()
# Out:
# 0.3571428571428571

# %%
partition=pfc_simaneal[0].index
nparts=len(partition)
partition
# Out:
# {0: set([0, 2, 4, 5, 8, 10, 11, 12]),
#  1: set([1, 3, 6, 9, 13, 14, 15]),
#  2: set([7])}

# %%
bx_part=dict()
for ipart in range(nparts):
    bx_part_items=[]
    for i,y in enumerate(partition[ipart]):
        bx_part_items.append(lit_relabel_dict[y])
    bx_part[ipart]= set(bx_part_items)

# %%
bx_part
# Out:
# {0: set(['47/12', '9/46v', '44', '46dr', '45A', '45B', '9/46d', '8Ad']),
#  1: set(['8B', '46v', 'D9', '46d', '46f', 'M9', 'L9']),
#  2: set(['46vr'])}

# %%
lit2_simaneal[0].modularity()
# Out:
# 0.3571428571428571

# %%
partition=lit2_simaneal[0].index
nparts=len(partition)
partition
# Out:
# {0: set([1, 3, 4, 6, 8, 9, 10]), 1: set([0, 2, 5, 7, 11, 12])}

# %%
bx_part=dict()
for ipart in range(nparts):
    bx_part_items=[]
    for i,y in enumerate(partition[ipart]):
        bx_part_items.append(lit_relabel_dict2[y])
    bx_part[ipart]= set(bx_part_items)

# %%
bx_part
# Out:
# {0: set(['47/12', '9/46v', '44', '45A', '45B', '9/46d', '8Ad']),
#  1: set(['8B', '46v', 'D9', '46d', 'M9', 'L9'])}

# %%
bx_read=blumex.make_readable_bx_partition(lit2_simaneal, lit_relabel_dict2)

# %%
bx_read
# Out:
# {0: set(['47/12', '9/46v', '44', '45A', '45B', '9/46d', '8Ad']),
#  1: set(['8B', '46v', 'D9', '46d', 'M9', 'L9'])}

# %%
test=mod.newman_partition(mod_lat6v_graph)

# %%
test.index_as_node_names()
# Out:
# [['24d', '46d', 'M9', 'F2', 'F6', '8B', 'D9'],
#  ['46v', '46f', 'PS', '46dr', '6Vb', '6Va', 'L9', '46vr'],
#  ['M2-FL'],
#  ['24a',
#   '47/12',
#   '8Ad',
#   '44',
#   'PrCO',
#   'F7',
#   '9/46v',
#   'M2-HL',
#   '45A',
#   '45B',
#   '9/46d',
#   '4c']]
